# %%
import autogen
import json
import os
from sentence_transformers import SentenceTransformer
import numpy as np
from collections import defaultdict
import statistics
import matplotlib.pyplot as plt
import copy
import random
import sys
from tqdm.auto import tqdm
import re
# Out:
# /homes/rpujari/scratch/anaconda3/envs/work/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %% [markdown]
# # Parameters (Needs to be configured to the specific task)

# %%
def read_task_output_file(file_name):
    """
    Read the task output logs
    
    Args:
    - file_name (str): The single log file that wants to get evaluated.
    """
    f = open( file_name,"r").readlines()
    output_dictionary = ""
    for line in f:
        if "is_correct" not in line and "correct_ans" not in line and  "check_result"  not in line:
            output_dictionary += line
        elif "is_correct" in line:
            correctness = line.replace(",","").split(":")[-1].rstrip().strip()
    return [output_dictionary,correctness]

# %%
task_prompt_instr = open('../naacl2024submission/scaling_and_verification/relevance_prompt.txt').read().strip()
success1 = open('../naacl2024submission/scaling_and_verification/successful_relevance_1.txt').read().strip()
success2 = open('../naacl2024submission/scaling_and_verification/successful_relevance_2.txt').read().strip()
failure1 = open('../naacl2024submission/scaling_and_verification/unsuccessful_relevance_1.txt').read().strip()
failure2 = open('../naacl2024submission/scaling_and_verification/unsuccessful_relevance_2.txt').read().strip()

# %%
# prompt related
task = {
    "name": "Providing relevance judgment for a social norm to a given Chinese conversation", 
    "description": task_prompt_instr,
    "examples": f'''
        Successful Example #1:
        {success1}

        Successful Example #2:
        {success2}

        Unsuccessful Example #1:
        {failure1}

        Unsuccessful Example #2:
        {failure2}
    '''.strip()
}

sys_msg = f"""Task: {task["name"]}.
Task description: {task["description"]}
{task['examples']}
"""

# %%
# parameters, input path and output path
num_critic_seeds = 15
num_quantifier_seeds = 3
critic_agent_output_path_prefix = "outputs/norm_relevance/criteria/task_based/norm_rel-autogen-"
final_summarized_criteria_output_path = "outputs/norm_relevance/final_filtered_criteria.json"
# task_logs_input_path = "logs/norm_relevance_logs/autogen"
quantifier_agent_one_at_a_time_output_path_prefix = "outputs/norm_relevance/evaluated_problems-"
quantifier_agent_all_at_once_output_path_prefix = "outputs/norm_relevance/15-seeds-all-in-one/evaluated_problems-"
quantifier_stdev_plot_output_path = "outputs/norm_relevance/mean_stdev_comparison.png"
adversarial_examples_output_path = "outputs/norm_relevance/adversarial_examples.json"
adversarial_testing_evaluated_results_output_path = "outputs/norm_relevance/adversarial_testing_evaluated_results.json"
quantifier_adversarial_testing_plot_output_path = "outputs/norm_relevance/adversarial_quantifier_performance.png"

# %%
import pickle
test_data = pickle.load(open('../naacl2024submission/self_verification_1.pkl', 'rb'))
tdata, gpt_data, resps, X, Y = test_data

# %%
# load the original logs (directory might be structured differently)
original_test_cases = {}

idx = 0
for prompt, label in gpt_data:
    original_test_cases[idx] = ['relevant' if label else 'irrelevant', prompt]
    idx += 1

# %%
# Which part of the task output to drop might be different
def create_adversarial_samples(text):
    original_sample = json.loads(text)
    adversarial_sample = copy.deepcopy(original_sample)
    adversarial_sample['messages'] = []
    
    for m in original_sample['messages']: 
        if m['role'] == 'assistant':
            original_content = m['content']
            original_content_list = list(filter(lambda x: len(x) > 0, original_content.replace('. ', '\n').split('\n')))
            frac = 0.5 
            inds = set(random.sample(list(range(len(original_content_list))), int(frac*len(original_content_list))))
            new_content_list = [n for i,n in enumerate(original_content_list) if i not in inds]
            new_content = '\n'.join(new_content_list)
            adversarial_sample['messages'].append({'content': new_content, 'role': 'assistant'})
        else:
            adversarial_sample['messages'].append(m)
    
    return json.dumps(adversarial_sample, indent=2)

# %%
# LLM API
# config_list = autogen.config_list_from_json(
#     "OAI_CONFIG_LIST",
# )

# %env AUTOGEN_USE_DOCKER=0
openai_key = '<put-your-key-here>' #Put your OpenAI key here
config_list = [{"model": "gpt-4o-mini", "api_key": openai_key}]
# Out:
# env: AUTOGEN_USE_DOCKER=0

# %% [markdown]
# # Checkpoint 1: Run CriticAgent Multiple Times

# %%
for i in range(num_critic_seeds):
        
    critic = autogen.AssistantAgent(
        name = "critic",
        llm_config = {"config_list": config_list,"cache_seed":i},
        system_message = """You are a helpful assistant. You suggest criteria for evaluating different tasks. They should be dinstinguishable, quantifieable and not redundant.
        Convert the evaluation criteria into a dictionary where the keys are the criteria.
        The value of each key is a dictionary as follows {"description": criteria description , "accepted_values": possible accepted inputs for this key}
        Make sure the keys are criteria for assessing the given task.  "accepted_values" include the acceptable inputs for each key that are fine-grained and preferrably mlti-graded levels. "description" includes the criterion description.
        Return the dictionary."""
    )

    critic_user = autogen.UserProxyAgent(
        name = "critic_user",
        max_consecutive_auto_reply = 0,  # terminate without auto-reply
        human_input_mode = "NEVER",
    )

    gen_criteria = critic_user.initiate_chat(critic, message=sys_msg)
    criteria = critic_user.last_message()
    with open(critic_agent_output_path_prefix + str(i) + ".json", "w") as cr_file:
        try:
            crit_content = re.findall(re.compile('{[\s\S]+}'), criteria["content"])[0]
            crit_dict = json.loads(crit_content)
            json.dump(crit_dict,cr_file,indent=2)
        except:
            print(sys.exc_info()[0])
# Out:
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance": {
#         "description": "Judging the relevance of the social norm to the context of the conversation.",
#         "accepted_values": ["relevant", "irrelevant"]
#     },
#     "justification_quality": {
#         "description": "Quality and clarity of the justification provided for the relevance decision.",
#         "accepted_values": [
#             "strong",  # Well-supported, clear, and thorough justification.
#             "moderate",  # Some support and clarity, but lacking depth.
#             "weak"  # Little to no support, unclear or irrelevant justification.
#         ]
#     },
#     "cultural_understanding": {
#         "description": "Demonstrated understanding of the cultural context and significance of the social norm.",
#         "accepted_values": [
#             "high",  # Exceptional understanding of context and cultural implications.
#             "medium",  # Decent understanding but may miss some nuances.
#             "low"  # Poor understanding or misinterpretation of cultural significance.
#         ]
#     },
#     "contextual_relevance": {
#         "description": "Assessment of how well the social norm applies to the specific situation and relationships in the conversation.",
#         "accepted_values": [
#             "high",  # Norm directly and strongly applies to the context.
#             "medium",  # Norm has some relevance but not strongly applicable.
#             "low"  # Norm is generally irrelevant to the context.
#         ]
#     },
#     "clarity_of_explanation": {
#         "description": "Clarity and coherence of the explanation given in the judgment.",
#         "accepted_values": [
#             "clear",  # Easy to understand with clear ideas and structure.
#             "somewhat_clear",  # Understandable but could be more coherent.
#             "unclear"  # Difficult to understand, poorly structured.
#         ]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# <class 'json.decoder.JSONDecodeError'>
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "cultural_relevance": {
#         "description": "Assessing how closely the social norm aligns with the context and elements present in the conversation.",
#         "accepted_values": ["high relevance", "moderate relevance", "low relevance", "no relevance"]
#     },
#     "relationship_context": {
#         "description": "Evaluating the nature of the relationships between the individuals involved in the conversation and how this affects the relevance judgment of the social norm.",
#         "accepted_values": ["close family", "distant family", "friends", "acquaintances", "strangers"]
#     },
#     "communication_style": {
#         "description": "Analyzing the tone and manner of the conversation, which may indicate adherence to or deviation from cultural norms.",
#         "accepted_values": ["formal", "informal", "neutral", "polite", "dismissive"]
#     },
#     "setting_of_conversation": {
#         "description": "Considering the environment in which the conversation takes place (e.g., home, workplace, public place) as an influencing factor on cultural social norms.",
#         "accepted_values": ["home", "office", "public space", "social gathering", "private place"]
#     },
#     "age_difference": {
#         "description": "Looking at the age difference between the speakers and how it plays a role in the relevance of the social norm.",
#         "accepted_values": ["significant age gap", "similar age", "younger speaker", "older speaker", "no age gap"]
#     },
#     "topic_of_conversation": {
#         "description": "Identifying the primary subject being discussed in the conversation and its relationship to the social norm.",
#         "accepted_values": ["family matters", "love/relationships", "work-related", "social issues", "health and wellness"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance_judgment": {
#         "description": "Assessment of whether the social norm is pertinent to the context of the conversation.",
#         "accepted_values": ["relevant", "irrelevant"]
#     },
#     "justification": {
#         "description": "Explanation of the reasoning behind the relevance judgment, highlighting specific aspects of the conversation and the social norm.",
#         "accepted_values": ["string"]  # a detailed explanation
#     },
#     "age_dynamics": {
#         "description": "Consideration of the age gaps between participants and how that affects the relevance of the social norm.",
#         "accepted_values": ["young", "middle-aged", "elderly", "mixed"]
#     },
#     "relationship_type": {
#         "description": "The nature of the relationship between participants (e.g., family, friends, colleagues) which impacts social norm relevance.",
#         "accepted_values": ["family", "friends", "colleagues", "acquaintances"]
#     },
#     "setting": {
#         "description": "The environment where the conversation takes place (e.g., home, workplace, public) which can influence social norms.",
#         "accepted_values": ["home", "work", "public", "private"]
#     },
#     "topic_of_conversation": {
#         "description": "The main subject of the conversation that may relate to the social norm being judged.",
#         "accepted_values": ["family", "work", "relationships", "education"]
#     },
#     "cultural_context": {
#         "description": "Assessment of how well the social norm is understood and accepted within the broader cultural framework.",
#         "accepted_values": ["well-understood", "moderately understood", "poorly understood"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# <class 'json.decoder.JSONDecodeError'>
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```json
# {
#     "relevance_judgment": {
#         "description": "Evaluates how closely the social norm aligns with the context of the conversation.",
#         "accepted_values": {
#             "1": "relevant",
#             "0": "irrelevant"
#         }
#     },
#     "justification_quality": {
#         "description": "Assesses the clarity and depth of the justification provided for the relevance judgment.",
#         "accepted_values": {
#             "1": "well-articulated and comprehensive",
#             "0": "vague or unclear"
#         }
#     },
#     "contextual_factors": {
#         "description": "Considers the importance of context-specific factors such as relationships, setting, and topics discussed.",
#         "accepted_values": {
#             "1": "strongly influences the relevance",
#             "0": "has little to no influence on the relevance"
#         }
#     },
#     "cultural_consistency": {
#         "description": "Evaluates how well the conversation aligns with broader Chinese cultural practices and beliefs.",
#         "accepted_values": {
#             "1": "highly consistent with cultural norms",
#             "0": "not consistent with cultural norms"
#         }
#     },
#     "communication_style": {
#         "description": "Examines the appropriateness of communication styles used in the conversation, considering factors such as politeness and indirectness.",
#         "accepted_values": {
#             "1": "appropriate and respectful",
#             "0": "inappropriate or disrespectful"
#         }
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "cultural_relevance": {
#         "description": "Examines how directly the social norm applies to the specific cultural context and nuances of the conversation.",
#         "accepted_values": ["not_relevant", "somewhat_relevant", "highly_relevant"]
#     },
#     "relationship_context": {
#         "description": "Assesses the nature of relationships between individuals in the conversation, including familial, professional, or friendly ties.",
#         "accepted_values": ["distant", "neutral", "close"]
#     },
#     "behavioural_conformance": {
#         "description": "Evaluates whether the actions and language of the individuals conform to the prescribed social norm.",
#         "accepted_values": ["non_conforming", "partially_conforming", "fully_conforming"]
#     },
#     "sociocultural_appropriateness": {
#         "description": "Determines if the social norm is contextually appropriate based on the setting (e.g., work vs. home environment).",
#         "accepted_values": ["inappropriate", "marginally_appropriate", "appropriate"]
#     },
#     "age_factor": {
#         "description": "Considers the ages of the individuals involved and how it influences the expectation of adherence to the social norm.",
#         "accepted_values": ["youth", "middle_age", "elderly"]
#     },
#     "climate_of_conversation": {
#         "description": "Evaluates the emotional tone of the conversation, such as joy, sadness, or neutrality.",
#         "accepted_values": ["negative", "neutral", "positive"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance_to_norm": {
#         "description": "This criterion assesses how closely the conversation aligns with the specified social norm, considering both direct and indirect compliance.",
#         "accepted_values": ["highly relevant", "relevant", "somewhat relevant", "irrelevant"]
#     },
#     "justification_clarity": {
#         "description": "This criterion evaluates how clearly the justification explains the decision made about the norm's relevance, ensuring it provides explicit connections to the conversation.",
#         "accepted_values": ["very clear", "clear", "somewhat clear", "unclear"]
#     },
#     "cultural_appropriateness": {
#         "description": "This criterion determines if the norms referenced are culturally appropriate for the context of the conversation, ensuring respect for cultural practices.",
#         "accepted_values": ["highly appropriate", "appropriate", "somewhat appropriate", "inappropriate"]
#     },
#     "contextual_factors_consideration": {
#         "description": "This criterion looks at how well the evaluator considers relevant contextual factors such as the relationships, settings, and topics of the conversation when assessing relevance.",
#         "accepted_values": ["thoroughly considered", "considered", "somewhat considered", "not considered"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance_of_cultural_norm": {
#         "description": "Assess how relevant the social norm is to the context of the conversation.",
#         "accepted_values": ["highly relevant", "relevant", "somewhat relevant", "not relevant"]
#     },
#     "justification_clarity": {
#         "description": "Determine how clearly the justification explains the connection between the social norm and the conversation.",
#         "accepted_values": ["very clear", "clear", "somewhat clear", "unclear"]
#     },
#     "contextual_considerations": {
#         "description": "Evaluate how well the response considers contextual factors such as relationships, settings, and conversation topics.",
#         "accepted_values": ["excellent", "good", "fair", "poor"]
#     },
#     "adherence_to_format": {
#         "description": "Check if the response adheres to the specified response format.",
#         "accepted_values": ["perfect adherence", "minor errors", "major errors", "no adherence"]
#     },
#     "cultural_accuracy": {
#         "description": "Assess how accurately the social norm reflects Chinese cultural practices.",
#         "accepted_values": ["very accurate", "accurate", "somewhat accurate", "inaccurate"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```json
# {
#     "relevance_judgment": {
#         "description": "Evaluates the overall relevance of the social norm to the given conversation context.",
#         "accepted_values": {
#             "0": "Irrelevant",
#             "1": "Relevant, but not strong",
#             "2": "Relevant"
#         }
#     },
#     "justification_quality": {
#         "description": "Assesses the clarity and completeness of the justification provided for the relevance judgment.",
#         "accepted_values": {
#             "0": "Poor justification, lacks clarity or detail",
#             "1": "Satisfactory justification, covers basic points",
#             "2": "Strong justification, provides comprehensive reasoning"
#         }
#     },
#     "contextual_factors": {
#         "description": "Considers additional elements such as age, relationships, and conversation settings that influence the relevance judgment.",
#         "accepted_values": {
#             "0": "No contextual factors considered",
#             "1": "Some contextual factors considered",
#             "2": "All relevant contextual factors thoroughly considered"
#         }
#     },
#     "cultural_significance": {
#         "description": "Evaluates the importance of the social norm in the context of Chinese culture.",
#         "accepted_values": {
#             "0": "Not culturally significant",
#             "1": "Some cultural significance",
#             "2": "Highly culturally significant"
#         }
#     },
#     "norm_application": {
#         "description": "Assesses how well the social norm is applied in the conversation.",
#         "accepted_values": {
#             "0": "Poor application, does not align with the norm",
#             "1": "Fair application, partially aligns with the norm",
#             "2": "Excellent application, fully aligns with the norm"
#         }
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "Cultural Relevance": {
#         "description": "The degree to which the social norm applies to the context of the conversation based on cultural practices.",
#         "accepted_values": ["low", "medium", "high"]
#     },
#     "Context Appropriateness": {
#         "description": "The suitability of the social norm considering the setting (work, family, friends) of the conversation.",
#         "accepted_values": ["not appropriate", "slightly appropriate", "appropriate"]
#     },
#     "Relationship Dynamics": {
#         "description": "The relevance of the social norm concerning the relationships (e.g., familial, friendship) between the individuals involved.",
#         "accepted_values": ["weak relationship", "neutral relationship", "strong relationship"]
#     },
#     "Age Considerations": {
# ...
#         "accepted_values": ["strong", "moderate", "weak"]
#     },
#     "norm_specificity": {
#         "description": "The specificity of the social norm being evaluated in relation to the conversation.",
#         "accepted_values": ["specific", "general"]
#     },
#     "cultural_alignment": {
#         "description": "How well the characters' actions in the conversation align with the social norm within the cultural context.",
#         "accepted_values": ["strong alignment", "moderate alignment", "weak alignment"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance_judgment": {
#         "description": "Judgment on whether the social norm is relevant to the conversation context.",
#         "accepted_values": ["relevant", "irrelevant"]
#     },
#     "justification_quality": {
#         "description": "Assessment of how well the justification explains the relationship between the social norm and the conversation.",
#         "accepted_values": ["poor", "fair", "good", "excellent"]
#     },
#     "consideration_of_context": {
#         "description": "Evaluation of how well the judge considers factors such as age, relationships, and setting in their decision.",
#         "accepted_values": ["low", "medium", "high"]
#     },
#     "clarity_of_response": {
#         "description": "Clarity and coherence of the justification provided in the response.",
#         "accepted_values": ["unclear", "somewhat clear", "clear", "very clear"]
#     },
#     "depth_of_analysis": {
#         "description": "Assessment of the depth of the analysis given in the justification, including references to specific elements of the conversation.",
#         "accepted_values": ["shallow", "moderate", "deep", "very deep"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "relevance": {
#         "description": "Determines whether the social norm applies to the context of the conversation.",
#         "accepted_values": ["relevant", "irrelevant"]
#     },
#     "justification_quality": {
#         "description": "Assesses the clarity and depth of the justification provided for the relevance judgment.",
#         "accepted_values": ["excellent", "good", "fair", "poor"]
#     },
#     "contextual_alignment": {
#         "description": "Evaluates how well the social norm aligns with the conversation's context, including relationships and settings.",
#         "accepted_values": ["high", "medium", "low"]
#     },
#     "cultural_accuracy": {
#         "description": "Measures the accuracy of the description of the social norm in relation to Chinese culture.",
#         "accepted_values": ["accurate", "mostly accurate", "somewhat accurate", "inaccurate"]
#     },
#     "specificity": {
#         "description": "Assesses how specific the judgment and justification are regarding the norms and context provided.",
#         "accepted_values": ["highly specific", "specific", "vague", "very vague"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
# critic_user (to critic):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Successful Example #1:
#         ### Input:
#
# Norm ID: 8
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 1. Respect for elders: Zuo Zhengpeng addresses Mrs. Xu as "伯母" (auntie) and shows respect by politely greeting her and accepting her invitation to enter the house.
#
# ### Response:
#
# Justification: Zuo Zhengpeng shows respect for Mrs. Xu by addressing her as "伯母" and politely greeting her, which aligns with the Chinese social norm of respect for elders.
# Relevance: relevant
#
#         Successful Example #2:
#         ### Input:
#
# Norm ID: 9
# Conversation from Chinese culture:
# 左正鵬(happiness): 伯母、您好，我是你麗華的同學呀！
# 徐母(happiness): 小左，快請進，屋裏坐！屋裏坐！我早就聽到閨女講到你的情況，我們歡迎你呀！
# 徐母(neutral): 老伴，你到代銷店裏去買瓶酒來，什麼“清明露”的都行。快去快回啊！
#
# Social Norm:
# 2. Hospitality: Mrs. Xu warmly welcomes Zuo Zhengpeng into the house, offering him a seat and expressing happiness at his visit.
#
# ### Response:
#
# Justification: In this conversation, Mrs. Xu demonstrates the social norm of hospitality by warmly welcoming Zuo Zhengpeng into her home and offering him a seat. This norm emphasizes the importance of showing kindness and generosity to guests, making them feel comfortable and valued in one's home.
# Relevance: Relevant
#
#         Unsuccessful Example #1:
#         ### Input:
#
# Conversation from Chinese culture:
# 左正鵬(sadness): 嗨，做男人真難哪！既要對付自己的老婆，又要防範外界女人對自己“人身”的侵犯！
# 左父(surprise): 正鵬，你剛纔說什麼？跟我再說一遍！
# 左正鵬(neutral): 爸，我沒有說什麼，我只說我們男人做事好難爲人的。別的沒說什麼呀！
# 左父(surprise): 正鵬我老實告訴你，你麗華不在家裏，晚上不能躥女人的門呀！
# 左正鵬(neutral): 爸，你這是什麼意思，你好像看到我什麼似的。
# 左父(neutral): 我能看到你什麼？我只是提醒提醒你而已！今後要注意下男女之間的是非！
#
# Social Norm:
# 1. Respect for parents: Children are expected to respect and obey their parents' authority.
#
# ### Response:
#
# Justification: In this conversation, the son is discussing the challenges of being a man and dealing with his wife and other women. The father then warns him about not getting involved with other women when his wife is not around. The father's reminder about respecting the boundaries between men and women can be seen as a reflection of the social norm of respect for parents, as he is advising his son to behave in a way that honors his marriage and family values.
#
# Relevance: Relevant
#
#         Unsuccessful Example #2:
#         ### Input:
#
# Norm ID: 136
# Conversation from Chinese culture:
# 左正鵬(neutral): 麗華，小孩的分娩期還有多久？
# 徐麗華(neutral): 大概在下個星期吧！
# 左正鵬(happiness): 哎喲，寶寶在動呢！
# 徐麗華(happiness): 看你那樣子羞死人的！
# 徐麗華(neutral): 急什麼，反正還有幾天時間，到時再說，你想早點當爸爸是嗎？
# 左正鵬(neutral): 不行！到時候就來不及了，還是先去醫院幾天等着好些，我們這裏交通又不方便，如果真的遇上了麻煩事，困難就大了。
#
# Social Norm:
# 1. Respect for elders: It is common in Chinese culture to show respect to older family members, such as parents and grandparents.
#
# ### Response:
#
# Justification: The conversation involves a couple discussing the imminent birth of their child. The husband expresses concern about the wife's well-being and suggests going to the hospital early to avoid any potential complications.
# Relevance: Relevant
#
#
# --------------------------------------------------------------------------------
# critic (to critic_user):
#
# ```python
# evaluation_criteria = {
#     "clarity": {
#         "description": "The degree to which the reasoning behind the relevance judgment is clear and understandable.",
#         "accepted_values": ["1 - very unclear", "2 - unclear", "3 - neutral", "4 - clear", "5 - very clear"]
#     },
#     "contextuality": {
#         "description": "The extent to which the judgment considers the specific context of the conversation including relationships, settings, and cultural nuances.",
#         "accepted_values": ["1 - not contextualized", "2 - poorly contextualized", "3 - moderately contextualized", "4 - well contextualized", "5 - very well contextualized"]
#     },
#     "appropriateness": {
#         "description": "How well the social norm applies to the situation discussed in the conversation.",
#         "accepted_values": ["1 - not appropriate", "2 - minimally appropriate", "3 - somewhat appropriate", "4 - appropriate", "5 - highly appropriate"]
#     },
#     "cultural relevance": {
#         "description": "The degree to which the social norm reflects significant aspects of Chinese culture relevant to the conversation.",
#         "accepted_values": ["1 - not culturally relevant", "2 - minimally relevant", "3 - somewhat relevant", "4 - culturally relevant", "5 - highly culturally relevant"]
#     },
#     "consistency": {
#         "description": "The consistency of the judgment with established norms and expectations in Chinese cultural contexts.",
#         "accepted_values": ["1 - highly inconsistent", "2 - inconsistent", "3 - neutral", "4 - consistent", "5 - highly consistent"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------

# %% [markdown]
# # Checkpoint 2: Generate Summarized Criteria

# %%
# load data
crit_dicts = []

for i in range(num_critic_seeds):
    with open(critic_agent_output_path_prefix + str(i) + ".json",'r') as fptr:
        try:
            fstr = fptr.read().strip()
            if fstr.startswith('```json'):
                fstr = fstr[7:-3]
            criteria = json.loads(fstr)
            if criteria:
                crit_dicts.append(criteria)
        except:
            print(sys.exc_info()[0])
# Out:
# <class 'json.decoder.JSONDecodeError'>
# <class 'json.decoder.JSONDecodeError'>

# %%
criteria_summarizer_message_base = """You are a helpful assistant. You suggest criteria for evaluating different tasks. They should be dinstinguishable, quantifieable and not redundant.
A criteria dictionary is a dictionary where the keys are the criteria. 
The value of each key is a dictionary as follows {"description": criteria description , "accepted_values": possible accepted inputs for this key}
You will be given a list of criteria dictionaries that others have suggested. They will be of varying qualities, and some of them will be synonymous.
You should pick the best 25 distinct criteria for the task, and each criterion's corresponding best decription and range of accepted values.
Your output should be a criteria dictionary containing the 25 distinct criteria you have picked.
Make sure the keys are criteria for assessing the given task.  "accepted_values" include the acceptable inputs for each key that are fine-grained and preferrably mlti-graded levels. "description" includes the criterion description.
Return only the dictionary, and in json format."""

criteria_summarizer = autogen.AssistantAgent(
    name = "criteria_summarizer",
    llm_config = {"config_list": config_list},
    system_message = criteria_summarizer_message_base,
)

# %%
def get_summarized_criteria(crit_dicts):
    criteria_summarizer_user = autogen.UserProxyAgent(
        name = "criteria_summarizer_user",
        max_consecutive_auto_reply = 0,  # terminate without auto-reply
        human_input_mode = "NEVER",
    )    

    message = f"""Task: {task["name"]}.
Task description: {task["description"]}
Suggested criteria: {crit_dict}
"""

    criteria_summarizer_user.initiate_chat(criteria_summarizer, message=message)
    # return the last received from the criteria summarizer
    return criteria_summarizer_user.last_message()["content"]

# %%
summarized_criteria_list = []

for i in range(len(crit_dicts) // 25):
    summarized_criteria_list.append(get_summarized_criteria(crit_dicts[i*25 : (i+1)*25]))

final_summarized_criteria = get_summarized_criteria(summarized_criteria_list)
# Out:
# criteria_summarizer_user (to criteria_summarizer):
#
# Task: Providing relevance judgment for a social norm to a given Chinese conversation.
# Task description: You are a helpful assistant. Your task is to judge the relevance of a Chinese cultural social norm to the sitatution in a given conversation. Consider factors such as age of the people involved, relationships between them, settings of the conversations such as work, family or friends, topic of conversation and so on. Respond with "relevant"/"irrelevant" label and provide a justifcation for your decision. Strictly format your answer as: Justification: <justification>
# Relevance: <decision>
# Suggested criteria: {'clarity': {'description': 'The degree to which the reasoning behind the relevance judgment is clear and understandable.', 'accepted_values': ['1 - very unclear', '2 - unclear', '3 - neutral', '4 - clear', '5 - very clear']}, 'contextuality': {'description': 'The extent to which the judgment considers the specific context of the conversation including relationships, settings, and cultural nuances.', 'accepted_values': ['1 - not contextualized', '2 - poorly contextualized', '3 - moderately contextualized', '4 - well contextualized', '5 - very well contextualized']}, 'appropriateness': {'description': 'How well the social norm applies to the situation discussed in the conversation.', 'accepted_values': ['1 - not appropriate', '2 - minimally appropriate', '3 - somewhat appropriate', '4 - appropriate', '5 - highly appropriate']}, 'cultural relevance': {'description': 'The degree to which the social norm reflects significant aspects of Chinese culture relevant to the conversation.', 'accepted_values': ['1 - not culturally relevant', '2 - minimally relevant', '3 - somewhat relevant', '4 - culturally relevant', '5 - highly culturally relevant']}, 'consistency': {'description': 'The consistency of the judgment with established norms and expectations in Chinese cultural contexts.', 'accepted_values': ['1 - highly inconsistent', '2 - inconsistent', '3 - neutral', '4 - consistent', '5 - highly consistent']}}
#
#
# --------------------------------------------------------------------------------
# criteria_summarizer (to criteria_summarizer_user):
#
# ```json
# {
#     "clarity": {
#         "description": "The degree to which the reasoning behind the relevance judgment is clear and understandable.",
#         "accepted_values": ["1 - very unclear", "2 - unclear", "3 - neutral", "4 - clear", "5 - very clear"]
#     },
#     "contextuality": {
#         "description": "The extent to which the judgment considers the specific context of the conversation including relationships, settings, and cultural nuances.",
#         "accepted_values": ["1 - not contextualized", "2 - poorly contextualized", "3 - moderately contextualized", "4 - well contextualized", "5 - very well contextualized"]
#     },
#     "appropriateness": {
#         "description": "How well the social norm applies to the situation discussed in the conversation.",
#         "accepted_values": ["1 - not appropriate", "2 - minimally appropriate", "3 - somewhat appropriate", "4 - appropriate", "5 - highly appropriate"]
#     },
#     "cultural relevance": {
#         "description": "The degree to which the social norm reflects significant aspects of Chinese culture relevant to the conversation.",
#         "accepted_values": ["1 - not culturally relevant", "2 - minimally relevant", "3 - somewhat relevant", "4 - culturally relevant", "5 - highly culturally relevant"]
#     },
#     "consistency": {
#         "description": "The consistency of the judgment with established norms and expectations in Chinese cultural contexts.",
#         "accepted_values": ["1 - highly inconsistent", "2 - inconsistent", "3 - neutral", "4 - consistent", "5 - highly consistent"]
#     },
#     "relationship dynamics": {
#         "description": "The consideration of the relationships between the individuals involved in the conversation and how that influences the relevance of the social norm.",
#         "accepted_values": ["1 - not considered", "2 - weakly considered", "3 - moderately considered", "4 - strongly considered", "5 - very strongly considered"]
#     },
#     "setting analysis": {
#         "description": "Evaluation of how the setting of the conversation (e.g., family, workplace, casual gathering) impacts the relevance of the social norm.",
#         "accepted_values": ["1 - no impact", "2 - minor impact", "3 - moderate impact", "4 - significant impact", "5 - critical impact"]
#     },
#     "norm visibility": {
#         "description": "The extent to which the social norm is visible or recognized in the context of the conversation.",
#         "accepted_values": ["1 - not visible", "2 - slightly visible", "3 - moderately visible", "4 - visible", "5 - very visible"]
#     },
#     "social hierarchy": {
#         "description": "How well the judgment incorporates aspects of social hierarchy or status within the Chinese cultural context.",
#         "accepted_values": ["1 - not addressed", "2 - poorly addressed", "3 - addressed", "4 - well addressed", "5 - very well addressed"]
#     },
#     "timeliness": {
#         "description": "Consider how the relevance of the social norm may change over time or in different historical contexts.",
#         "accepted_values": ["1 - not timely", "2 - slightly timely", "3 - moderately timely", "4 - timely", "5 - very timely"]
#     },
#     "evidence": {
#         "description": "The amount and quality of evidence or examples provided to support the relevance judgment.",
#         "accepted_values": ["1 - no evidence", "2 - minimal evidence", "3 - some evidence", "4 - good evidence", "5 - strong evidence"]
#     },
#     "norm specificity": {
#         "description": "The degree to which the social norm discussed is specific and detailed rather than vague.",
#         "accepted_values": ["1 - very vague", "2 - vague", "3 - somewhat specific", "4 - specific", "5 - very specific"]
#     },
#     "emotional tone": {
#         "description": "Evaluation of how the emotional tone of the conversation affects the relevance of the social norm.",
#         "accepted_values": ["1 - negative impact", "2 - slight negative impact", "3 - neutral impact", "4 - slight positive impact", "5 - positive impact"]
#     },
#     "discourse style": {
#         "description": "The impact of the discourse style (formal, informal, persuasive, etc.) on the relevance of the social norm.",
#         "accepted_values": ["1 - no impact", "2 - minimal impact", "3 - moderate impact", "4 - significant impact", "5 - critical impact"]
#     },
#     "dissonance level": {
#         "description": "The level of dissonance between the social norm and the expressed opinions or behaviors in the conversation.",
#         "accepted_values": ["1 - highly dissonant", "2 - moderately dissonant", "3 - neutral", "4 - somewhat aligned", "5 - highly aligned"]
#     },
#     "cultural evolution": {
#         "description": "Consideration of how modern trends or changes in society may affect the relevance of traditional social norms.",
#         "accepted_values": ["1 - outdated", "2 - slightly outdated", "3 - somewhat relevant", "4 - relevant", "5 - highly relevant"]
#     },
#     "clarity of norm": {
#         "description": "The clarity and precision of the specific social norm being referenced in the conversation.",
#         "accepted_values": ["1 - very unclear", "2 - unclear", "3 - somewhat clear", "4 - clear", "5 - very clear"]
#     },
#     "collective perspective": {
#         "description": "How well the judgment considers the views of the collective society versus individual perspectives.",
#         "accepted_values": ["1 - individual-focused", "2 - slightly collective", "3 - moderately collective", "4 - largely collective", "5 - entirely collective"]
#     },
#     "norm adoption": {
#         "description": "Recognition of how widely the social norm is adopted or practiced within Chinese society.",
#         "accepted_values": ["1 - not adopted", "2 - rarely adopted", "3 - somewhat adopted", "4 - widely adopted", "5 - universally adopted"]
#     },
#     "age sensitivity": {
#         "description": "The extent to which the relevance judgment is sensitive to the age differences of the individuals involved.",
#         "accepted_values": ["1 - not sensitive", "2 - slightly sensitive", "3 - moderately sensitive", "4 - sensitive", "5 - very sensitive"]
#     },
#     "analytic depth": {
#         "description": "The depth of analysis provided in the reasoning for the relevance judgment.",
#         "accepted_values": ["1 - very superficial", "2 - superficial", "3 - moderate depth", "4 - deep", "5 - very deep"]
#     },
#     "feedback responsiveness": {
#         "description": "The degree to which the judgment accounts for feedback or reactions from the individuals in the conversation.",
#         "accepted_values": ["1 - not responsive", "2 - slightly responsive", "3 - moderately responsive", "4 - responsive", "5 - very responsive"]
#     },
#     "rule conformity": {
#         "description": "How closely the judgment conforms to established social rules and expectations within the context.",
#         "accepted_values": ["1 - highly non-conformant", "2 - non-conformant", "3 - somewhat conformant", "4 - conformant", "5 - highly conformant"]
#     }
# }
# ```
#
# --------------------------------------------------------------------------------

# %%
final_summarized_criteria = final_summarized_criteria[7:-3].strip()

# %%
final_summarized_criteria = json.loads(final_summarized_criteria)

# convert to a list of words
conversion_dict_final = {}
for criteria in final_summarized_criteria:
    conversion_dict_final[' '.join(criteria.lower().split('_'))] = criteria

final_list_of_criteria = list(conversion_dict_final.keys())

# %%
# set up synonymous detection
def find_synonymous_in_list(word_list, threshold=0.75):
    model = SentenceTransformer('paraphrase-MiniLM-L6-v2', device='cuda:1')  # Load a pre-trained SentenceTransformer model
    embeddings = model.encode(word_list, convert_to_tensor=True)  # Compute embeddings for the word list
    embeddings = embeddings.cpu()
    

    processed_words = set()
    used_in_synonyms = set()
    synonymous_dict = {}

    for i, word in enumerate(word_list):
        if word not in processed_words and word not in used_in_synonyms:
            synonymous_list = []
            for j, other_word in enumerate(word_list):
                if i != j:
                    cosine_sim = np.dot(embeddings[i], embeddings[j]) / (np.linalg.norm(embeddings[i]) * np.linalg.norm(embeddings[j]))
                    if cosine_sim > threshold:
                        synonymous_list.append(other_word)
                        used_in_synonyms.add(other_word)
            if synonymous_list or word not in synonymous_dict:  # Check if synonymous_list is not empty or word is not already added
                synonymous_list = list(set(synonymous_list))  # Remove duplicates from the list
                synonymous_list.sort()  # Sort the list to make the output consistent
                synonymous_dict[word] = synonymous_list
            processed_words.add(word)
    
    return synonymous_dict

# %%
synonymous_dict = find_synonymous_in_list(final_list_of_criteria)
final_criteria = {}
for criteria in synonymous_dict:
    final_criteria[criteria] = final_summarized_criteria[conversion_dict_final[criteria]]
# Out:
# /homes/rpujari/scratch/anaconda3/envs/work/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
with open(final_summarized_criteria_output_path, "w") as outfile:
    json.dump(final_criteria, outfile, indent = 4)

# %% [markdown]
# # Checkpoint 3: Run QuantifierAgent (All Criteria At Once Version)

# %%
# load the criteria
with open(final_summarized_criteria_output_path) as crit_file:
    criteria = json.load(crit_file)

# %%
def run_quantifier_agent_all_criteria_at_once(num_seeds):
    quantifier_message_base = """You are a helpful assistant. You quantify the output of different tasks based on the given criteria.
    The criterion is given in a dictionary format where each key is a distinct criteria.
    The value of each key is a dictionary as follows {"description": criteria description , "accepted_values": possible accepted inputs for this key}
    You are going to quantify each of the crieria for a given task based on the task decription.
    Return a dictionary where the keys are the criteria and the values are the assessed performance based on accepted values for each criteria.
    Return only the dictionary as a json format string and nothing else."""

    for seed in range(num_seeds):
        outcome = {}
        quantifier = autogen.AssistantAgent(
            name = "quantifier",
            llm_config = {"config_list": config_list,"cache_seed":seed},
            system_message = quantifier_message_base)

        for gameid in tqdm(original_test_cases):
            actual_label, test_case = original_test_cases[gameid]
    
            result = {"actual_success": actual_label, "estimated_performance": {}}

            quantifier_user = autogen.UserProxyAgent(
                name = "quantifier_user",
                max_consecutive_auto_reply = 0,  # terminate without auto-reply
                human_input_mode = "NEVER",
            )
            cq_results = quantifier_user.initiate_chat(quantifier, message = sys_msg + \
                                            "Evaluation dictionary: " + str(criteria) + "\n" + \
                                            "actual test case to evaluate: " + test_case)
            quantified_result = quantifier_user.last_message()["content"]
            
            quantified_result = re.findall(re.compile('{[\s\S]+}'), quantified_result)[0]
            try:
                result["estimated_performance"] = json.loads(quantified_result)
            except:
                result["estimated_performance"] = {}
                print(sys.exc_info()[0])
                
            outcome[gameid] = json.dumps(result)
                
                            
        # store the evaluated problems
        with open(quantifier_agent_all_at_once_output_path_prefix + str(seed) + ".json","w") as file:
            json.dump(outcome,file,indent=2)

# %%
run_quantifier_agent_all_criteria_at_once(num_quantifier_seeds)

# %% [markdown]
# # Checkpoint 4: Run QuantifierAgent (One Criteria At a Time Version)

# %%
def run_quantifier_agent_one_criterion_a_time(num_seeds):
    quantifier_message_base = """You are a helpful assistant. You quantify the output of different tasks based on the given criteria.
        You will be given a criterion a dictionary as follows {"description": criterion description , "accepted_values": possible accepted inputs for this key}.
        You are going to evaluate the test case against the given criterion for the given task.
        Return the assessed performance based on accepted values for each criteria, which must be one of the values provided in the accepted_values list.
        Return only the assessed performance and nothing else"""

    for seed in range(num_seeds):
        outcome = {}
        quantifier = autogen.AssistantAgent(
            name = "quantifier",
            llm_config = {"config_list": config_list,"cache_seed":seed},
            system_message = quantifier_message_base)

        for gameid in tqdm(original_test_cases):
            actual_label, test_case = original_test_cases[gameid]
    
            result = {"actual_success": actual_label, "estimated_performance": {}}

            for criterion in criteria:
                quantifier_user = autogen.UserProxyAgent(
                    name = "quantifier_user",
                    max_consecutive_auto_reply = 0,  # terminate without auto-reply
                    human_input_mode = "NEVER",
                )
                cq_results = quantifier_user.initiate_chat(quantifier, message = sys_msg + \
                                                "Evaluation criterion: " + criterion + "\n" + \
                                                "Evaluation dictionary: " + str(criteria[criterion]) + "\n" + \
                                                "actual test case to evaluate: " + test_case)
                quantified_result = quantifier_user.last_message()["content"]

                quantified_result = re.findall(re.compile('{[\s\S]+}'), quantified_result)[0]
                try:
                    result["estimated_performance"][criterion] = quantified_result
                except:
                    result["estimated_performance"][criterion] = {}
                    print(sys.exc_info()[0])
                        
            outcome[gameid] = json.dumps(result)
                            
        # store the evaluated problems
        with open(quantifier_agent_one_at_a_time_output_path_prefix + str(seed) + ".json","w") as file:
            json.dump(outcome,file,indent=2)

# %%
run_quantifier_agent_one_criterion_a_time(num_quantifier_seeds)

# %% [markdown]
# # Checkpoint 5: Plot QuantifierAgent Standard Deviation

# %%
# convert accepted value to score
level2score = defaultdict(lambda: defaultdict(int))
for criterion in criteria:
     score = 0
     for v in criteria[criterion]["accepted_values"]:
        level2score[criterion][v] = score
        score += 1
print(level2score)

# %%
def get_stdevs_from_quantified_output(num_seeds, path_prefix):
    results = defaultdict(lambda: defaultdict(list)) # result[criterion][game] gives a list of num_seeds scores for that game 
    key_errors = defaultdict(int)
    
    for seed in range(num_seeds):
        # Load outcome data for the current seed
        with open(path_prefix + str(seed) + ".json", 'r') as file:
            outcome = json.load(file)
    
            for game in outcome:
                gameid = game.strip(".json")
                quantified_result = json.loads(outcome[game])['estimated_performance']

                for criterion in quantified_result:
                    quantified_result[criterion] = str(quantified_result[criterion])
                    cleaned_level = quantified_result[criterion].strip("'")
                    results[criterion][gameid].append(level2score[criterion][cleaned_level])
        
    stdevs = defaultdict(lambda: defaultdict(float))
    
    for criterion in results:
        for game in results[criterion]:
            stdevs[criterion][game] = statistics.stdev(results[criterion][game])
        
    stdevs_list = {}
    for criterion in stdevs:
        stdevs_list[criterion] = []
        for game in stdevs[criterion]:
            stdevs_list[criterion].append(stdevs[criterion][game])

    mean_stdevs = {}
    for criterion in stdevs_list:
        mean_stdevs[criterion] = statistics.mean(stdevs_list[criterion])

    return (stdevs_list, mean_stdevs, key_errors, results)

# %%
exp1_stdevs_list, exp1_mean_stdevs, exp1_key_errors, exp1_results = \
get_stdevs_from_quantified_output(num_quantifier_seeds, quantifier_agent_all_at_once_output_path_prefix)
exp2_stdevs_list, exp2_mean_stdevs, exp2_key_errors, exp2_results = \
get_stdevs_from_quantified_output(num_quantifier_seeds, quantifier_agent_one_at_a_time_output_path_prefix)

# %%
for key in original_test_cases:
    print(key)
    print(original_test_cases[key])
    for cr in exp1_results:
        print(cr, exp1_results[cr][str(key)])
    break

# %%
def plot_quantifier_stdev():
    plt.figure(figsize=(12, 8))
    bar_width = 0.2
    index = np.arange(len(criteria))
    
    criteria_names = list(criteria.keys())
    
    exp1_data = []
    exp2_data = []
    for criterion in criteria_names:
        exp1_data.append(exp1_mean_stdevs[criterion])
        exp2_data.append(exp2_mean_stdevs[criterion])
    
    plt.bar(index , exp1_data, bar_width, label=f"all in one", color="blue", capsize=5)
    plt.bar(index + bar_width, exp2_data, bar_width, label=f"one criterion per prompt", color="orange", capsize=5)
    
    plt.xlabel("Criteria", fontsize=16)
    plt.ylabel("Mean Standard Deviation", fontsize=16)
    plt.xticks(index + bar_width / 2, criteria_names, rotation=90, fontsize=14)
    plt.legend(loc="upper center", fontsize=14, bbox_to_anchor=(0.5, 1), ncol=3)  # Adjust legend placement and ncol
    plt.tight_layout()  # Adjust subplot parameters to fit the labels
    plt.savefig(quantifier_stdev_plot_output_path)
    plt.show()

# %%
plot_quantifier_stdev()

# %% [markdown]
# # Checkpoint 6: Generate Adversarial Samples

# %%
adversarial_test_cases = {}
for gameid in original_test_cases:
    actual_label, test_case = original_test_cases[gameid]

    adversarial_test_case = create_adversarial_samples(test_case)
    adversarial_test_cases[gameid] = adversarial_test_case
    
with open(adversarial_examples_output_path,"w") as file:
    json.dump(adversarial_test_cases,file,indent=2)

# %% [markdown]
# # Checkpoint 7: Run QuantifierAgent on Adversarial Samples

# %%
def run_quantifier_on_adversarial_samples():
    quantifier_message_base = """You are a helpful assistant. You quantify the output of different tasks based on the given criteria.
        You will be given a criterion a dictionary as follows {"description": criterion description , "accepted_values": possible accepted inputs for this key}.
        You are going to evaluate the test case against the given criterion for the given task.
        Return the assessed performance based on accepted values for each criteria, which must be one of the values provided in the accepted_values list.
        Return only the assessed performance and nothing else"""

    quantifier = autogen.AssistantAgent(
        name = "quantifier",
        llm_config = {"config_list": config_list},
        system_message = quantifier_message_base)

    outcome = {}
    
    for gameid in original_test_cases:
        actual_label, test_case = original_test_cases[gameid]
        adversarial_test_case = adversarial_test_cases[gameid]

        result = {"actual_success": actual_label, "estimated_performance": {}}

        for criterion in criteria:
            quantifier_user = autogen.UserProxyAgent(
                name = "quantifier_user",
                max_consecutive_auto_reply = 0,  # terminate without auto-reply
                human_input_mode = "NEVER",
            )
            cq_results = quantifier_user.initiate_chat(quantifier, message = sys_msg + \
                                            "Evaluation criterion: " + criterion + "\n" + \
                                            "Evaluation dictionary: " + str(criteria[criterion]) + "\n" + \
                                            "actual test case to evaluate: " + test_case)
            quantified_result = quantifier_user.last_message()["content"]

            original_result = quantified_result

            quantifier_user = autogen.UserProxyAgent(
                name = "quantifier_user",
                max_consecutive_auto_reply = 0,  # terminate without auto-reply
                human_input_mode = "NEVER",
            )
            cq_results = quantifier_user.initiate_chat(quantifier, message = sys_msg + \
                                            "Evaluation criterion: " + criterion + "\n" + \
                                            "Evaluation dictionary: " + str(criteria[criterion]) + "\n" + \
                                            "actual test case to evaluate: " + adversarial_test_case)
            quantified_result = quantifier_user.last_message()["content"]

            adversarial_result = quantified_result

            result['estimated_performance'][criterion] = [original_result, adversarial_result]        
                
        outcome[gameid] = json.dumps(result)
                        
    # store the evaluated problems
    with open(adversarial_testing_evaluated_results_output_path,"w") as file:
        json.dump(outcome,file,indent=2)

# %%
run_quantifier_on_adversarial_samples()

# %% [markdown]
# # Checkpoint 8: Plot QuantifierAgent Adversarial Testing Performance

# %%
# load data
with open(adversarial_testing_evaluated_results_output_path) as file:
    original_outcome = json.load(file)

original_adversarial_exp_scores = defaultdict(lambda: defaultdict(list))

for game in original_outcome:
    evaluated_results = json.loads(original_outcome[game])['estimated_performance']
    for criterion in evaluated_results:
        original_level, adversarial_level = evaluated_results[criterion]
        
        original_score = level2score[criterion][original_level.strip('"').strip("'")]
        adversarial_score = level2score[criterion][adversarial_level.strip('"').strip("'")]
        
        original_adversarial_exp_scores[criterion]['original'].append(original_score)
        original_adversarial_exp_scores[criterion]['adversarial'].append(adversarial_score)

original_averages = defaultdict(lambda: defaultdict(float))

for criterion in original_adversarial_exp_scores:
    original_averages[criterion]["original"] =  statistics.mean(original_adversarial_exp_scores[criterion]["original"])
    original_averages[criterion]["adversarial"] =  statistics.mean(original_adversarial_exp_scores[criterion]["adversarial"])

# %%
def plot_quantifier_adversarial_testing():
    plt.figure(figsize=(12, 8))
    bar_width = 0.2
    index = np.arange(len(criteria))
    
    criteria_names = list(criteria.keys())
    
    exp1_data = []
    exp2_data = []
    
    for criterion in criteria_names:
        exp1_data.append(original_averages[criterion]['original'])
        exp2_data.append(original_averages[criterion]['adversarial'])
    
    plt.bar(index , exp1_data, bar_width, label=f"original sample", color="darkblue", capsize=5)
    plt.bar(index + bar_width, exp2_data, bar_width, label=f"adversarial sample", color="lightblue", capsize=5)
    
    plt.xlabel("Criteria", fontsize=16)
    plt.ylabel("Average Quantified Score", fontsize=16)
    plt.xticks(index + bar_width / 2, criteria_names, rotation=90, fontsize=14)
    plt.legend(loc="upper center", fontsize=14, bbox_to_anchor=(0.5, 1), ncol=3)  # Adjust legend placement and ncol
    plt.tight_layout()  # Adjust subplot parameters to fit the labels
    plt.savefig(quantifier_adversarial_testing_plot_output_path)
    plt.show()

# %%
plot_quantifier_adversarial_testing()
